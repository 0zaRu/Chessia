# %% [markdown]
# <h3>0.0 CARGA DE BIBLIOTECAS, VARIABLES, CLASES Y MÉTODOS IMPORTANTES</h3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Dropout, LSTM, Dense, Embedding
import pickle
import json
import os
import sys

num_lilith = '05'
archivo_json_original = '../../Chessia_Data_Convert/Target Data/original/Datos-V2.json'
archivo_json_expansion = '../../Chessia_Data_Convert/Target Data/expansion/Datos-V2.json'
tokens_lilith = "../../Chessia_Data_Convert/TokensGenerator/general_tokens_v1.pkl"

class Partida:
    def __init__(self):
        self.movimientos = []
        self.resultado = None

# Función para cargar partidas en lotes
def cargar_partidas_por_rango(archivo_json_original, inicio=0, fin=None):
    total_movimientos = []
    total_resultados = []
    with open(archivo_json_original, 'r') as file:
        # Carga el contenido completo como una lista de objetos JSON
        lista_json = json.load(file)
        
        if fin is None or fin > len(lista_json):
            fin = len(lista_json)

        # Itera sobre cada objeto JSON en la lista
        for i in range(inicio, fin):
            total_movimientos.append(lista_json[i]['partida']['movimientos'])
            total_resultados.append(lista_json[i]['partida']['resultado'])
            
    return total_movimientos, total_resultados

def ver_tablas(history):
    fig, axs = plt.subplots(2, 1, figsize=(10, 10))

    epocas = range(1, len(history.history['loss']) + 1)

    # Graficar la precisión
    axs[0].plot(epocas, history.history['accuracy'], 'r', label='Precisión en entrenamiento')
    axs[0].plot(epocas, history.history['val_accuracy'], 'b', label='Precisión en validación')
    axs[0].set_title('Precisión en entrenamiento y validación')
    axs[0].set_xlabel('Épocas')
    axs[0].set_ylabel('Precisión')
    axs[0].legend()

    # Graficar la pérdida
    axs[1].plot(epocas, history.history['loss'], 'r', label='Pérdida en entrenamiento')
    axs[1].plot(epocas, history.history['val_loss'], 'b', label='Pérdida en validación')
    axs[1].set_title('Pérdida en entrenamiento y validación')
    axs[1].set_xlabel('Épocas')
    axs[1].set_ylabel('Pérdida')
    axs[1].legend()

    plt.tight_layout()  # Ajustar el diseño para evitar superposiciones
    plt.show()


class PlotMetricsCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        try:
            if self.model.history:
                ver_tablas(self.model.history)

        except Exception as e:
            print("Error al mostrar la gráfica:", e)

# %% [markdown]
# <h3>3.0 PROCESADO DE DATOS DE LILITH - USA ProcesadorPGN_V2 Y EXTENSIÓN DE PERTIDAS</h3>

# %%
# Convertir el generador en una lista y extraer la primera tupla
recogido = cargar_partidas_por_rango(archivo_json_original, fin=100000)
recogido += cargar_partidas_por_rango(archivo_json_expansion)

movimientos = recogido[0]
resultados = recogido[1]

# Crear y ajustar el tokenizador
tokenizer = Tokenizer()
with open(tokens_lilith, "rb") as f:
    tokenizer = pickle.load(f)

# Convertir todas las jugadas a secuencias de números enteros y luego a tensores válidos
movimientos_tokenized = tokenizer.texts_to_sequences(movimientos)
movimientos_tokenized = pad_sequences(movimientos_tokenized, maxlen=500, padding="pre")

resultados_tokenized = tf.one_hot([int(resultado) for resultado in resultados], depth=3)  # 3 clases: empate, victoria blanca, victoria negra

tensor_mov_entrena = tf.constant(movimientos_tokenized[:int(len(movimientos_tokenized) * 0.8) ])
tensor_res_entrena = tf.constant(resultados_tokenized [:int(len(resultados_tokenized)  * 0.8) ])
tensor_mov_prueba =  tf.constant(movimientos_tokenized[ int(len(movimientos_tokenized) * 0.8):])
tensor_res_prueba =  tf.constant(resultados_tokenized [ int(len(resultados_tokenized)  * 0.8):])

# %% [markdown]
# <h3>3.1 LILITH - DEFINICIÓN, ENTRENAMIENTO Y GRÁFICAS DE DATOS CON POCOS VALORES</h3>

# %% [markdown]
# <h4>&ensp;&ensp;3.1.1 CREACIÓN DEL MODELO</h4>

# %%
# Definir el modelo
modelo = tf.keras.Sequential([
    Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=128),
    LSTM(units=256, dropout=0.2, recurrent_dropout=0.2, return_sequences=True),
    LSTM(units=128, dropout=0.2, recurrent_dropout=0.2),
    # Dense(units=256, activation='relu'),
    # Dropout(0.3),
    Dense(units=3, activation='softmax')
])

# Compilar el modelo
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) 
modelo.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <h4>&ensp;&ensp;3.1.2 ENTRENAMIENTO</h4>

# %%
history = None
try:
    # Definir callbacks
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    checkpoint = ModelCheckpoint(filepath='modelo_checkpoint.keras', save_best_only=True)
    plot_metrics = PlotMetricsCallback()

    try:
        modelo = tf.keras.models.load_model('modelo_checkpoint.keras')
        print("Checkpoint cargado. Continuando entrenamiento desde el último punto guardado...\n\n")
    except:
        print("No se encontró un checkpoint existente. Iniciando un nuevo entrenamiento...\n\n")

    # Entrenar el modelo con los callbacks
    history = modelo.fit(
        tensor_mov_entrena,
        tensor_res_entrena,
        epochs=15,
        initial_epoch=0,  # Especificar la primera época a ejecutar
        batch_size=256,
        validation_data=(tensor_mov_prueba, tensor_res_prueba),
        callbacks=[early_stopping, checkpoint, plot_metrics]
        # callbacks=[early_stopping, checkpoint]
    )

    # Guardar el modelo final
    modelo.save("lilith"+num_lilith+".keras")

    # Evaluar el modelo en los datos de prueba
    loss, accuracy = modelo.evaluate(tensor_mov_prueba, tensor_res_prueba)
    print("\n\nLoss en los datos de prueba:", loss)
    print("Precisión en los datos de prueba:", accuracy)

except:
    if history is not None:
        ver_tablas(history)
    else:
        exc_type, exc_value, exc_traceback = sys.exc_info()
        print(f"Error: {exc_type.__name__}: {exc_value}")
# Out:
# Checkpoint cargado. Continuando entrenamiento desde el último punto guardado...
#
#
# Epoch 11/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 2993s 11s/step - accuracy: 0.8174 - loss: 0.4595 - val_accuracy: 0.7786 - val_loss: 0.5450
# Epoch 12/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 3090s 11s/step - accuracy: 0.8142 - loss: 0.4709 - val_accuracy: 0.7836 - val_loss: 0.5346
# Epoch 13/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 2958s 11s/step - accuracy: 0.8286 - loss: 0.4285 - val_accuracy: 0.7858 - val_loss: 0.5322
# Epoch 14/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 3226s 12s/step - accuracy: 0.8378 - loss: 0.4141 - val_accuracy: 0.7896 - val_loss: 0.5299
# Epoch 15/15
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 2473s 9s/step - accuracy: 0.8431 - loss: 0.3972 - val_accuracy: 0.7926 - val_loss: 0.5336
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 533s 568ms/step - accuracy: 0.7914 - loss: 0.5284
#
#
# Loss en los datos de prueba: 0.529927670955658
# Precisión en los datos de prueba: 0.7896000146865845

# %% [markdown]
# <h4>&ensp;&ensp;3.1.3 ESTADÍSTICAS Y GRÁFICAS</h4>

# %%
ver_tablas(history)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ver_tablas(history)
#
# Cell In[6], line 41, in ver_tablas(history)
#      38 def ver_tablas(history):
#      39     fig, axs = plt.subplots(2, 1, figsize=(10, 10))
# ---> 41     epocas = range(1, len(history.history['loss']) + 1)
#      43     # Graficar la precisión
#      44     axs[0].plot(epocas, history.history['accuracy'], 'r', label='Precisión en entrenamiento')
#
# AttributeError: 'NoneType' object has no attribute 'history'

# %% [markdown]
# <h3>3.2 PRUEBA DE PREDICCIÓN LILITH</h3>

# %% [markdown]
# <h4>&ensp;&ensp;3.2.1 RECOGIDA DE DATOS Y TOKENS</h4>

# %%
movimientos, resultados = cargar_partidas_por_rango(archivo_json_original, inicio=100000)

tokenizer = Tokenizer()
with open(tokens_lilith, "rb") as f:
    tokenizer = pickle.load(f)

tensor_mov_pred = tf.constant(pad_sequences(tokenizer.texts_to_sequences(movimientos), maxlen=500, padding="pre"))

# %% [markdown]
# <h4>&ensp;&ensp;3.2.2 PREDICCIÓN Y MUESTRA DE DATOS</h4>

# %%
np.set_printoptions(suppress=True, precision=4)

lilith = tf.keras.models.load_model("lilith"+num_lilith+".keras")

res_pred = lilith.predict(tensor_mov_pred)
aciertos = sumaAciertos = 0

for i in range(len(res_pred)):
    if int(resultados[i]) != int(np.argmax(res_pred[i])): char = '❌'
    else: 
        char = '✅'
        aciertos += 1
        sumaAciertos += res_pred[i][np.argmax(res_pred[i])]

    print(f"Predicción: {str(res_pred[i]):>22} -- Dice: {np.argmax(res_pred[i])} -- Real: {resultados[i]}  {char}  --- Aciertos: {aciertos:>5}/{i+1:<5} - {int(aciertos/(i+1)*100):>3}%")
# Out:
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 61s 575ms/step
# Predicción: [0.8271 0.0616 0.1112] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:     1/1     - 100%
# Predicción: [0.7928 0.1932 0.014 ] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:     1/2     -  50%
# Predicción: [0.2266 0.3694 0.404 ] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:     1/3     -  33%
# Predicción: [0.0409 0.9319 0.0271] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:     2/4     -  50%
# Predicción: [0.0621 0.937  0.0009] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:     3/5     -  60%
# Predicción: [0.0229 0.9747 0.0024] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:     4/6     -  66%
# Predicción: [0.1838 0.7943 0.0218] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:     5/7     -  71%
# Predicción: [0.1219 0.0213 0.8568] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:     6/8     -  75%
# Predicción: [0.1761 0.8004 0.0235] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:     6/9     -  66%
# Predicción: [0.0885 0.0114 0.9001] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:     6/10    -  60%
# Predicción: [0.3937 0.5881 0.0182] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:     6/11    -  54%
# Predicción: [0.4681 0.5058 0.0261] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:     7/12    -  58%
# Predicción: [0.0482 0.0031 0.9487] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:     8/13    -  61%
# Predicción: [0.3675 0.602  0.0305] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:     8/14    -  57%
# Predicción: [0.2704 0.0035 0.7261] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:     9/15    -  60%
# Predicción: [0.0288 0.9341 0.0371] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    10/16    -  62%
# Predicción: [0.1929 0.0148 0.7922] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    11/17    -  64%
# Predicción: [0.11   0.8313 0.0588] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    12/18    -  66%
# Predicción: [0.2918 0.6904 0.0179] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:    12/19    -  63%
# Predicción: [0.1714 0.7218 0.1067] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    13/20    -  65%
# Predicción: [0.0642 0.904  0.0318] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    14/21    -  66%
# Predicción: [0.0307 0.9677 0.0016] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    15/22    -  68%
# Predicción: [0.0051 0.9942 0.0008] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    16/23    -  69%
# Predicción: [0.0406 0.9446 0.0148] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    17/24    -  70%
# Predicción: [0.1406 0.0853 0.7741] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:    17/25    -  68%
# Predicción: [0.3037 0.69   0.0063] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    18/26    -  69%
# Predicción: [0.3274 0.0134 0.6592] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    19/27    -  70%
# Predicción: [0.0579 0.0195 0.9225] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    20/28    -  71%
# Predicción: [0.091  0.0228 0.8863] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    21/29    -  72%
# Predicción: [0.6476 0.0601 0.2923] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    22/30    -  73%
# Predicción: [0.9308 0.0657 0.0035] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    23/31    -  74%
# Predicción: [0.0037 0.9955 0.0008] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    24/32    -  75%
# Predicción: [0.6065 0.0944 0.2991] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    25/33    -  75%
# Predicción: [0.5662 0.4273 0.0065] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    26/34    -  76%
# Predicción: [0.8779 0.1107 0.0114] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    27/35    -  77%
# Predicción: [0.7229 0.0116 0.2655] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    28/36    -  77%
# Predicción: [0.9473 0.047  0.0057] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    29/37    -  78%
# Predicción: [0.9882 0.0075 0.0042] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    30/38    -  78%
# Predicción: [0.9911 0.0082 0.0008] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    31/39    -  79%
# Predicción: [0.1196 0.8525 0.0279] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    32/40    -  80%
# Predicción: [0.8089 0.0837 0.1074] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    33/41    -  80%
# Predicción: [0.6363 0.3006 0.0631] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    34/42    -  80%
# Predicción: [0.7593 0.1037 0.137 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    35/43    -  81%
# Predicción: [0.9618 0.0327 0.0054] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    36/44    -  81%
# Predicción: [0.8409 0.1561 0.003 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    37/45    -  82%
# Predicción: [0.8338 0.0125 0.1537] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    38/46    -  82%
# Predicción: [0.9915 0.0063 0.0022] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    39/47    -  82%
# Predicción: [0.1838 0.3834 0.4329] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:    39/48    -  81%
# Predicción: [0.9166 0.0165 0.0669] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    40/49    -  81%
# Predicción: [0.9476 0.0014 0.051 ] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:    40/50    -  80%
# Predicción: [0.0396 0.9424 0.018 ] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    41/51    -  80%
# Predicción: [0.6047 0.3682 0.027 ] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:    41/52    -  78%
# Predicción: [0.9885 0.0079 0.0036] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    42/53    -  79%
# Predicción: [0.772  0.0925 0.1356] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    43/54    -  79%
# Predicción: [0.0465 0.9406 0.013 ] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    44/55    -  80%
# Predicción: [0.9948 0.0001 0.0051] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    45/56    -  80%
# Predicción: [0.9389 0.0058 0.0554] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    46/57    -  80%
# Predicción: [0.8742 0.0214 0.1044] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    47/58    -  81%
# Predicción: [0.5407 0.0262 0.4331] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    48/59    -  81%
# Predicción: [0.1179 0.8635 0.0186] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:    48/60    -  80%
# Predicción: [0.3509 0.6252 0.0239] -- Dice: 1 -- Real: 2  ❌  --- Aciertos:    48/61    -  78%
# Predicción: [0.6415 0.2697 0.0888] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    49/62    -  79%
# Predicción: [0.9751 0.0125 0.0124] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    50/63    -  79%
# Predicción: [0.5768 0.4196 0.0036] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    51/64    -  79%
# Predicción: [0.0757 0.9117 0.0127] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    52/65    -  80%
# Predicción: [0.1666 0.8278 0.0056] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:    52/66    -  78%
# Predicción: [0.1162 0.8774 0.0064] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:    52/67    -  77%
# Predicción: [0.425  0.0227 0.5523] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    53/68    -  77%
# Predicción: [0.7238 0.0249 0.2513] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:    53/69    -  76%
# Predicción: [0.0161 0.0053 0.9786] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    54/70    -  77%
# Predicción: [0.1778 0.7964 0.0258] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    55/71    -  77%
# Predicción: [0.0357 0.9171 0.0472] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:    55/72    -  76%
# Predicción: [0.9962 0.0031 0.0008] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    56/73    -  76%
# Predicción: [0.0713 0.0714 0.8573] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    57/74    -  77%
# Predicción: [0.992  0.0071 0.0009] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    58/75    -  77%
# Predicción: [0.3517 0.2247 0.4236] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:    58/76    -  76%
# Predicción: [0.9929 0.0065 0.0006] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    59/77    -  76%
# Predicción: [0.1973 0.8002 0.0026] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    60/78    -  76%
# Predicción: [0.071  0.9248 0.0042] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    61/79    -  77%
# Predicción: [0.9996 0.0003 0.0002] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    62/80    -  77%
# Predicción: [0.1575 0.8315 0.011 ] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:    62/81    -  76%
# Predicción: [0.9582 0.0083 0.0335] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    63/82    -  76%
# Predicción: [0.0204 0.9732 0.0064] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    64/83    -  77%
# Predicción: [0.9922 0.0071 0.0007] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    65/84    -  77%
# Predicción: [0.9201 0.077  0.0029] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    66/85    -  77%
# Predicción: [0.0641 0.9329 0.0029] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    67/86    -  77%
# Predicción: [0.4404 0.2565 0.3031] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    68/87    -  78%
# Predicción: [0.3888 0.0163 0.5949] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    69/88    -  78%
# Predicción: [0.096  0.8828 0.0212] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:    69/89    -  77%
# Predicción: [0.9964 0.0002 0.0033] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    70/90    -  77%
# Predicción: [0.1275 0.8549 0.0175] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    71/91    -  78%
# Predicción: [0.791  0.0084 0.2005] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    72/92    -  78%
# Predicción: [0.0919 0.8962 0.0119] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    73/93    -  78%
# Predicción: [0.8508 0.0034 0.1458] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    74/94    -  78%
# Predicción: [0.95   0.007  0.0431] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    75/95    -  78%
# Predicción: [0.9436 0.0549 0.0015] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    76/96    -  79%
# Predicción: [0.7082 0.2713 0.0206] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:    76/97    -  78%
# Predicción: [0.0146 0.0018 0.9836] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    77/98    -  78%
# Predicción: [0.024  0.9681 0.0079] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    78/99    -  78%
# Predicción: [0.6059 0.1735 0.2206] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:    78/100   -  78%
# Predicción: [0.4931 0.0163 0.4906] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    79/101   -  78%
# Predicción: [0.6668 0.0058 0.3275] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:    79/102   -  77%
# Predicción: [0.2681 0.0051 0.7267] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:    79/103   -  76%
# Predicción: [0.37   0.0285 0.6015] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:    79/104   -  75%
# Predicción: [0.285  0.7074 0.0077] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    80/105   -  76%
# Predicción: [0.9359 0.0617 0.0024] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    81/106   -  76%
# Predicción: [0.1136 0.8841 0.0023] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    82/107   -  76%
# Predicción: [0.9479 0.0143 0.0378] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    83/108   -  76%
# Predicción: [0.2581 0.6595 0.0824] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    84/109   -  77%
# Predicción: [0.858  0.0055 0.1366] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:    84/110   -  76%
# Predicción: [0.6121 0.0349 0.353 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    85/111   -  76%
# Predicción: [0.0675 0.8983 0.0343] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    86/112   -  76%
# Predicción: [0.0313 0.0206 0.9481] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    87/113   -  76%
# Predicción: [0.1162 0.8748 0.0091] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    88/114   -  77%
# Predicción: [0.4693 0.004  0.5267] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    89/115   -  77%
# Predicción: [0.0432 0.9553 0.0015] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    90/116   -  77%
# Predicción: [0.1808 0.8073 0.012 ] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:    90/117   -  76%
# Predicción: [0.1945 0.7729 0.0326] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    91/118   -  77%
# Predicción: [0.053  0.0121 0.9349] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    92/119   -  77%
# Predicción: [0.934  0.0605 0.0055] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    93/120   -  77%
# Predicción: [0.8987 0.0969 0.0045] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    94/121   -  77%
# Predicción: [0.6118 0.0182 0.37  ] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:    94/122   -  77%
# Predicción: [0.7461 0.0927 0.1613] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    95/123   -  77%
# Predicción: [0.8238 0.0369 0.1392] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    96/124   -  77%
# Predicción: [0.0021 0.0005 0.9974] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:    97/125   -  77%
# Predicción: [0.8964 0.0314 0.0723] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:    98/126   -  77%
# Predicción: [0.0142 0.0008 0.985 ] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:    98/127   -  77%
# Predicción: [0.0035 0.996  0.0005] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:    99/128   -  77%
# Predicción: [0.0149 0.9816 0.0036] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   100/129   -  77%
# Predicción: [0.0683 0.0392 0.8924] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   101/130   -  77%
# Predicción: [0.815  0.1567 0.0283] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   102/131   -  77%
# Predicción: [0.8228 0.0515 0.1257] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   103/132   -  78%
# Predicción: [0.887  0.1093 0.0037] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   104/133   -  78%
# Predicción: [0.9928 0.0054 0.0018] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   105/134   -  78%
# Predicción: [0.2963 0.6977 0.006 ] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   106/135   -  78%
# Predicción: [0.9642 0.0037 0.0322] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   107/136   -  78%
# Predicción: [0.4935 0.0436 0.4629] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   107/137   -  78%
# Predicción: [0.431  0.5039 0.0651] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   107/138   -  77%
# Predicción: [0.1286 0.81   0.0614] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   108/139   -  77%
# Predicción: [0.3658 0.5055 0.1287] -- Dice: 1 -- Real: 2  ❌  --- Aciertos:   108/140   -  77%
# Predicción: [0.5902 0.3999 0.0099] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   108/141   -  76%
# Predicción: [0.3978 0.091  0.5112] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   109/142   -  76%
# Predicción: [0.7446 0.0676 0.1879] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   110/143   -  76%
# Predicción: [0.2225 0.0451 0.7325] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   110/144   -  76%
# Predicción: [0.2077 0.0329 0.7594] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   110/145   -  75%
# Predicción: [0.7414 0.1484 0.1102] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   111/146   -  76%
# Predicción: [0.0874 0.1639 0.7486] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:   111/147   -  75%
# Predicción: [0.1913 0.024  0.7847] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   111/148   -  75%
# Predicción: [0.9233 0.0715 0.0052] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   112/149   -  75%
# Predicción: [0.9776 0.0094 0.0131] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   113/150   -  75%
# Predicción: [0.9805 0.0153 0.0042] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   114/151   -  75%
# Predicción: [0.0559 0.9209 0.0232] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   115/152   -  75%
# Predicción: [0.197  0.7785 0.0244] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   116/153   -  75%
# Predicción: [0.9526 0.0256 0.0218] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   117/154   -  75%
# Predicción: [0.8741 0.1096 0.0163] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   118/155   -  76%
# Predicción: [0.0881 0.872  0.0399] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   119/156   -  76%
# Predicción: [0.5478 0.4129 0.0393] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   120/157   -  76%
# Predicción: [0.9893 0.0106 0.0001] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   121/158   -  76%
# Predicción: [0.6444 0.3491 0.0066] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   122/159   -  76%
# Predicción: [0.586  0.3961 0.0179] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   122/160   -  76%
# Predicción: [0.0069 0.0008 0.9923] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   122/161   -  75%
# Predicción: [0.3739 0.3699 0.2563] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   123/162   -  75%
# Predicción: [0.0487 0.0119 0.9394] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   124/163   -  76%
# Predicción: [0.0118 0.9863 0.0019] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   125/164   -  76%
# Predicción: [0.0593 0.9167 0.0239] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   125/165   -  75%
# Predicción: [0.0899 0.9031 0.007 ] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   125/166   -  75%
# Predicción: [0.3658 0.5418 0.0924] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   126/167   -  75%
# Predicción: [0.9714 0.0018 0.0269] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   127/168   -  75%
# Predicción: [0.9427 0.003  0.0543] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   128/169   -  75%
# Predicción: [0.7806 0.053  0.1664] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   129/170   -  75%
# Predicción: [0.0055 0.9937 0.0008] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   130/171   -  76%
# Predicción: [0.3285 0.0139 0.6576] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   130/172   -  75%
# Predicción: [0.0363 0.958  0.0056] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   130/173   -  75%
# Predicción: [0.6501 0.0904 0.2596] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   131/174   -  75%
# Predicción: [0.2731 0.678  0.0489] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   131/175   -  74%
# Predicción: [0.9868 0.0116 0.0016] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   132/176   -  75%
# Predicción: [0.3096 0.1575 0.5329] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   132/177   -  74%
# Predicción: [0.1964 0.2851 0.5185] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:   132/178   -  74%
# Predicción: [0.9757 0.0142 0.0101] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   133/179   -  74%
# Predicción: [0.9566 0.0187 0.0247] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   134/180   -  74%
# Predicción: [0.9707 0.0225 0.0068] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   135/181   -  74%
# Predicción: [0.9366 0.0048 0.0586] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   136/182   -  74%
# Predicción: [0.9686 0.0282 0.0032] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   137/183   -  74%
# Predicción: [0.195  0.7728 0.0322] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   138/184   -  75%
# Predicción: [0.2135 0.5841 0.2024] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   138/185   -  74%
# Predicción: [0.0122 0.9857 0.0021] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   139/186   -  74%
# Predicción: [0.1022 0.0105 0.8873] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   140/187   -  74%
# Predicción: [0.8653 0.1322 0.0025] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   140/188   -  74%
# Predicción: [0.8757 0.1107 0.0136] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   141/189   -  74%
# Predicción: [0.1269 0.0223 0.8508] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   142/190   -  74%
# Predicción: [0.1102 0.0021 0.8877] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   143/191   -  74%
# Predicción: [0.5807 0.1729 0.2464] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   144/192   -  75%
# Predicción: [0.9708 0.002  0.0272] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   145/193   -  75%
# Predicción: [0.0969 0.0179 0.8853] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   145/194   -  74%
# Predicción: [0.6401 0.3045 0.0554] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   146/195   -  74%
# Predicción: [0.0293 0.0077 0.963 ] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   147/196   -  75%
# Predicción: [0.7718 0.0363 0.1919] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   148/197   -  75%
# Predicción: [0.7816 0.21   0.0083] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   149/198   -  75%
# Predicción: [0.7091 0.2514 0.0396] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   150/199   -  75%
# Predicción: [0.9501 0.0026 0.0472] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   151/200   -  75%
# Predicción: [0.0226 0.9741 0.0033] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   152/201   -  75%
# Predicción: [0.9492 0.0418 0.0089] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   153/202   -  75%
# Predicción: [0.9063 0.0905 0.0032] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   154/203   -  75%
# Predicción: [0.9416 0.0165 0.0418] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   155/204   -  75%
# Predicción: [0.6072 0.3724 0.0204] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   155/205   -  75%
# Predicción: [0.0067 0.9923 0.0009] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   156/206   -  75%
# Predicción: [0.0378 0.0224 0.9398] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   157/207   -  75%
# Predicción: [0.0435 0.9471 0.0094] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   158/208   -  75%
# Predicción: [0.8591 0.1369 0.004 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   159/209   -  76%
# Predicción: [0.9514 0.0437 0.0049] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   160/210   -  76%
# Predicción: [0.2385 0.0061 0.7554] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   161/211   -  76%
# Predicción: [0.0214 0.9751 0.0036] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   162/212   -  76%
# Predicción: [0.9471 0.0072 0.0457] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   163/213   -  76%
# Predicción: [0.6661 0.1195 0.2144] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   164/214   -  76%
# Predicción: [0.8039 0.0319 0.1642] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   165/215   -  76%
# Predicción: [0.0194 0.018  0.9626] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:   165/216   -  76%
# Predicción: [0.8175 0.175  0.0075] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   166/217   -  76%
# Predicción: [0.2276 0.1041 0.6683] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   166/218   -  76%
# Predicción: [0.3792 0.2154 0.4054] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   166/219   -  75%
# Predicción: [0.838  0.0182 0.1438] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   167/220   -  75%
# Predicción: [0.9367 0.0482 0.0152] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   168/221   -  76%
# Predicción: [0.0524 0.9426 0.005 ] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   169/222   -  76%
# Predicción: [0.2425 0.7452 0.0122] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   170/223   -  76%
# Predicción: [0.9024 0.0079 0.0897] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   171/224   -  76%
# Predicción: [0.3263 0.0251 0.6486] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   171/225   -  76%
# Predicción: [0.5101 0.0061 0.4838] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   171/226   -  75%
# Predicción: [0.9349 0.0387 0.0264] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   171/227   -  75%
# Predicción: [0.1013 0.8957 0.0031] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   172/228   -  75%
# Predicción: [0.9983 0.0009 0.0007] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   173/229   -  75%
# Predicción: [0.0295 0.9688 0.0017] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   174/230   -  75%
# Predicción: [0.7201 0.0335 0.2464] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   175/231   -  75%
# Predicción: [0.089  0.9023 0.0087] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   176/232   -  75%
# Predicción: [0.8628 0.0106 0.1265] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   177/233   -  75%
# Predicción: [0.0317 0.0063 0.962 ] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   178/234   -  76%
# Predicción: [0.964  0.0328 0.0032] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   179/235   -  76%
# Predicción: [0.0315 0.0081 0.9604] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   180/236   -  76%
# Predicción: [0.5672 0.3214 0.1115] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   180/237   -  75%
# Predicción: [0.9514 0.0042 0.0444] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   181/238   -  76%
# Predicción: [0.734  0.1086 0.1574] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   181/239   -  75%
# Predicción: [0.9431 0.0557 0.0012] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   182/240   -  75%
# Predicción: [0.3839 0.5835 0.0326] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   182/241   -  75%
# Predicción: [0.9976 0.0008 0.0016] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   183/242   -  75%
# Predicción: [0.9513 0.0163 0.0324] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   184/243   -  75%
# Predicción: [0.0464 0.9262 0.0274] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   184/244   -  75%
# Predicción: [0.0451 0.0165 0.9383] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   185/245   -  75%
# Predicción: [0.002  0.9979 0.0001] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   186/246   -  75%
# Predicción: [0.0177 0.0022 0.9801] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   187/247   -  75%
# Predicción: [0.2072 0.3284 0.4644] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   187/248   -  75%
# Predicción: [0.7039 0.0387 0.2574] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   188/249   -  75%
# Predicción: [0.4801 0.4891 0.0307] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   189/250   -  75%
# Predicción: [0.1059 0.0288 0.8653] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   190/251   -  75%
# Predicción: [0.9896 0.0026 0.0077] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   191/252   -  75%
# Predicción: [0.3838 0.6128 0.0034] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   191/253   -  75%
# Predicción: [0.218  0.4611 0.3209] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   191/254   -  75%
# Predicción: [0.5179 0.0347 0.4474] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   192/255   -  75%
# Predicción: [0.977  0.0202 0.0029] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   193/256   -  75%
# Predicción: [0.2538 0.3061 0.4401] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:   193/257   -  75%
# Predicción: [0.9983 0.0004 0.0013] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   194/258   -  75%
# Predicción: [0.7395 0.2529 0.0076] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   194/259   -  74%
# Predicción: [0.0132 0.0025 0.9843] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   195/260   -  75%
# Predicción: [0.8974 0.0768 0.0258] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   196/261   -  75%
# Predicción: [0.3105 0.6822 0.0073] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   196/262   -  74%
# Predicción: [0.9492 0.0436 0.0072] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   197/263   -  74%
# Predicción: [0.0584 0.8992 0.0424] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   198/264   -  75%
# Predicción: [0.9321 0.0632 0.0046] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   199/265   -  75%
# Predicción: [0.3245 0.6513 0.0242] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   200/266   -  75%
# Predicción: [0.7704 0.0447 0.1849] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   200/267   -  74%
# Predicción: [0.6732 0.3041 0.0227] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   201/268   -  75%
# Predicción: [0.4008 0.5584 0.0409] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   201/269   -  74%
# Predicción: [0.4626 0.0135 0.524 ] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   202/270   -  74%
# Predicción: [0.0256 0.0069 0.9674] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   203/271   -  74%
# Predicción: [0.0471 0.952  0.0009] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   204/272   -  75%
# Predicción: [0.083  0.1575 0.7594] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   205/273   -  75%
# Predicción: [0.8831 0.1044 0.0125] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   206/274   -  75%
# Predicción: [0.0806 0.9135 0.0059] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   207/275   -  75%
# Predicción: [0.1786 0.8027 0.0187] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   208/276   -  75%
# Predicción: [0.0519 0.0006 0.9475] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   208/277   -  75%
# Predicción: [0.9862 0.0024 0.0113] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   209/278   -  75%
# Predicción: [0.9202 0.0758 0.004 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   210/279   -  75%
# Predicción: [0.0785 0.008  0.9134] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   211/280   -  75%
# Predicción: [0.9273 0.0058 0.0669] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   212/281   -  75%
# Predicción: [0.4146 0.0332 0.5521] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   212/282   -  75%
# Predicción: [0.7939 0.051  0.1551] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   213/283   -  75%
# Predicción: [0.1411 0.0248 0.8341] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   213/284   -  75%
# Predicción: [0.419  0.5567 0.0243] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   214/285   -  75%
# Predicción: [0.8565 0.0757 0.0679] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   215/286   -  75%
# Predicción: [0.3166 0.0594 0.624 ] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   216/287   -  75%
# Predicción: [0.03   0.0073 0.9627] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   217/288   -  75%
# Predicción: [0.0188 0.979  0.0022] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   218/289   -  75%
# Predicción: [0.9128 0.0787 0.0085] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   219/290   -  75%
# Predicción: [0.055  0.9413 0.0037] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   220/291   -  75%
# Predicción: [0.207  0.0271 0.7659] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   220/292   -  75%
# Predicción: [0.6765 0.3155 0.008 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   221/293   -  75%
# Predicción: [0.5903 0.4056 0.0041] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   221/294   -  75%
# Predicción: [0.0149 0.9828 0.0023] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   222/295   -  75%
# Predicción: [0.5656 0.0163 0.4181] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   223/296   -  75%
# Predicción: [0.3913 0.0127 0.5961] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   223/297   -  75%
# Predicción: [0.5438 0.4193 0.0369] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   224/298   -  75%
# Predicción: [0.8077 0.0292 0.1631] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   225/299   -  75%
# Predicción: [0.6814 0.0065 0.3121] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   226/300   -  75%
# Predicción: [0.0246 0.9718 0.0037] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   227/301   -  75%
# Predicción: [0.1425 0.8414 0.016 ] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   228/302   -  75%
# Predicción: [0.9233 0.0129 0.0637] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   229/303   -  75%
# Predicción: [0.0456 0.9513 0.0031] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   230/304   -  75%
# Predicción: [0.3833 0.5908 0.0259] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   230/305   -  75%
# Predicción: [0.9919 0.0079 0.0003] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   231/306   -  75%
# Predicción: [0.0572 0.9267 0.016 ] -- Dice: 1 -- Real: 2  ❌  --- Aciertos:   231/307   -  75%
# Predicción: [0.0558 0.9289 0.0153] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   232/308   -  75%
# Predicción: [0.9132 0.082  0.0048] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   233/309   -  75%
# Predicción: [0.9258 0.0691 0.0051] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   234/310   -  75%
# Predicción: [0.9402 0.0554 0.0044] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   235/311   -  75%
# Predicción: [0.2638 0.182  0.5542] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   235/312   -  75%
# Predicción: [0.9134 0.0177 0.0689] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   236/313   -  75%
# Predicción: [0.9385 0.004  0.0574] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   237/314   -  75%
# Predicción: [0.8978 0.0936 0.0086] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   238/315   -  75%
# Predicción: [0.0031 0.0006 0.9963] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   239/316   -  75%
# Predicción: [0.171  0.8224 0.0066] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   240/317   -  75%
# Predicción: [0.3699 0.5878 0.0423] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   240/318   -  75%
# Predicción: [0.0869 0.7684 0.1447] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   241/319   -  75%
# Predicción: [0.2977 0.0432 0.6591] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   241/320   -  75%
# Predicción: [0.0056 0.9931 0.0013] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   242/321   -  75%
# Predicción: [0.0715 0.7606 0.1679] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   243/322   -  75%
# Predicción: [0.2567 0.0404 0.7029] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:   243/323   -  75%
# Predicción: [0.2752 0.4074 0.3174] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   244/324   -  75%
# Predicción: [0.9328 0.0137 0.0535] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   245/325   -  75%
# Predicción: [0.1902 0.0276 0.7822] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   246/326   -  75%
# Predicción: [0.6439 0.3349 0.0212] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   247/327   -  75%
# Predicción: [0.0146 0.9832 0.0022] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   248/328   -  75%
# Predicción: [0.0268 0.9671 0.0061] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   249/329   -  75%
# Predicción: [0.8191 0.1025 0.0784] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   249/330   -  75%
# Predicción: [0.2441 0.7435 0.0125] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   250/331   -  75%
# Predicción: [0.8554 0.0188 0.1257] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   250/332   -  75%
# Predicción: [0.0459 0.9516 0.0025] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   251/333   -  75%
# Predicción: [0.6225 0.2834 0.0941] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   251/334   -  75%
# Predicción: [0.9734 0.0224 0.0042] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   252/335   -  75%
# Predicción: [0.1151 0.2439 0.641 ] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   253/336   -  75%
# Predicción: [0.2222 0.7143 0.0635] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   254/337   -  75%
# Predicción: [0.7846 0.1803 0.0351] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   255/338   -  75%
# Predicción: [0.893  0.0626 0.0444] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   255/339   -  75%
# Predicción: [0.9586 0.0383 0.0031] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   256/340   -  75%
# Predicción: [0.2431 0.6574 0.0994] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   256/341   -  75%
# Predicción: [0.1631 0.8279 0.009 ] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   256/342   -  74%
# Predicción: [0.7709 0.0127 0.2165] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   256/343   -  74%
# Predicción: [0.7258 0.0385 0.2357] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   256/344   -  74%
# Predicción: [0.0192 0.9777 0.0032] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   256/345   -  74%
# Predicción: [0.3283 0.0058 0.6659] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   256/346   -  73%
# Predicción: [0.5482 0.4436 0.0082] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   256/347   -  73%
# Predicción: [0.9534 0.0042 0.0423] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   257/348   -  73%
# Predicción: [0.596  0.1324 0.2715] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   257/349   -  73%
# Predicción: [0.846  0.1311 0.0229] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   258/350   -  73%
# Predicción: [0.6852 0.0258 0.289 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   259/351   -  73%
# Predicción: [0.7838 0.0578 0.1583] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   260/352   -  73%
# Predicción: [0.0833 0.032  0.8848] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   261/353   -  73%
# Predicción: [0.3506 0.6433 0.0061] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   261/354   -  73%
# Predicción: [0.7613 0.0336 0.2052] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   262/355   -  73%
# Predicción: [0.9638 0.0288 0.0074] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   263/356   -  73%
# Predicción: [0.1398 0.0347 0.8255] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   263/357   -  73%
# Predicción: [0.5027 0.489  0.0083] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   263/358   -  73%
# Predicción: [0.0746 0.9156 0.0099] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   263/359   -  73%
# Predicción: [0.0561 0.041  0.9029] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   263/360   -  73%
# Predicción: [0.0563 0.012  0.9317] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   264/361   -  73%
# Predicción: [0.0686 0.9185 0.0129] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   265/362   -  73%
# Predicción: [0.4031 0.0522 0.5448] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   265/363   -  73%
# Predicción: [0.0104 0.9873 0.0023] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   266/364   -  73%
# Predicción: [0.2898 0.107  0.6032] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   266/365   -  72%
# Predicción: [0.6689 0.3168 0.0143] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   267/366   -  72%
# Predicción:    [0.701 0.122 0.177] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   268/367   -  73%
# Predicción: [0.948  0.0431 0.0089] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   269/368   -  73%
# Predicción: [0.1742 0.8215 0.0044] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   270/369   -  73%
# Predicción: [0.0409 0.9547 0.0044] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   271/370   -  73%
# Predicción: [0.3883 0.5639 0.0478] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   272/371   -  73%
# Predicción: [0.5698 0.4145 0.0157] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   273/372   -  73%
# Predicción: [0.9292 0.0304 0.0404] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   274/373   -  73%
# Predicción: [0.7522 0.1237 0.1242] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   275/374   -  73%
# Predicción: [0.9269 0.0093 0.0638] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   276/375   -  73%
# Predicción: [0.9455 0.0489 0.0056] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   277/376   -  73%
# Predicción: [0.7274 0.1109 0.1617] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   278/377   -  73%
# Predicción: [0.9875 0.0047 0.0078] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   279/378   -  73%
# Predicción: [0.3141 0.0791 0.6067] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   279/379   -  73%
# Predicción: [0.1214 0.03   0.8486] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:   279/380   -  73%
# Predicción: [0.6134 0.1558 0.2309] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   280/381   -  73%
# Predicción: [0.2472 0.7413 0.0115] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   280/382   -  73%
# Predicción: [0.1383 0.816  0.0457] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   280/383   -  73%
# Predicción: [0.8472 0.1453 0.0074] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   281/384   -  73%
# Predicción: [0.0265 0.9722 0.0012] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   282/385   -  73%
# Predicción: [0.5384 0.4536 0.008 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   283/386   -  73%
# Predicción: [0.861  0.1353 0.0037] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   284/387   -  73%
# Predicción: [0.0337 0.9578 0.0084] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   284/388   -  73%
# Predicción: [0.0079 0.9907 0.0015] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   285/389   -  73%
# Predicción: [0.9179 0.0115 0.0707] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   286/390   -  73%
# Predicción: [0.4756 0.0314 0.4929] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   286/391   -  73%
# Predicción: [0.1113 0.8541 0.0345] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   287/392   -  73%
# Predicción: [0.1125 0.196  0.6915] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:   287/393   -  73%
# Predicción: [0.9312 0.064  0.0048] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   288/394   -  73%
# Predicción: [0.0974 0.7874 0.1152] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   289/395   -  73%
# Predicción: [0.9096 0.026  0.0644] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   290/396   -  73%
# Predicción: [0.8251 0.1195 0.0554] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   291/397   -  73%
# Predicción: [0.9892 0.009  0.0018] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   292/398   -  73%
# Predicción: [0.9414 0.0064 0.0522] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   292/399   -  73%
# Predicción: [0.036  0.0052 0.9588] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:   292/400   -  73%
# Predicción: [0.6303 0.337  0.0328] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   293/401   -  73%
# Predicción: [0.0055 0.9938 0.0007] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   294/402   -  73%
# Predicción: [0.9835 0.0148 0.0017] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   295/403   -  73%
# Predicción: [0.7338 0.2503 0.0159] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   296/404   -  73%
# Predicción: [0.7369 0.0464 0.2167] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   296/405   -  73%
# Predicción: [0.9264 0.0654 0.0082] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   297/406   -  73%
# Predicción: [0.2107 0.0876 0.7018] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   297/407   -  72%
# Predicción: [0.9566 0.0075 0.0359] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   298/408   -  73%
# Predicción: [0.0651 0.9283 0.0066] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   299/409   -  73%
# Predicción: [0.0136 0.9825 0.0038] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   300/410   -  73%
# Predicción: [0.6655 0.0666 0.2679] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   300/411   -  72%
# Predicción: [0.0636 0.8716 0.0649] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   301/412   -  73%
# Predicción: [0.289  0.0222 0.6889] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   302/413   -  73%
# Predicción: [0.5187 0.1894 0.2918] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   302/414   -  72%
# Predicción: [0.7665 0.0428 0.1906] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   303/415   -  73%
# Predicción: [0.7503 0.014  0.2357] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   304/416   -  73%
# Predicción: [0.9146 0.0582 0.0272] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   305/417   -  73%
# Predicción: [0.055  0.0209 0.9241] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   306/418   -  73%
# Predicción: [0.1619 0.8096 0.0285] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   307/419   -  73%
# Predicción: [0.9125 0.0833 0.0042] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   308/420   -  73%
# Predicción: [0.7616 0.0292 0.2093] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   309/421   -  73%
# Predicción: [0.9534 0.0433 0.0033] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   310/422   -  73%
# Predicción: [0.8562 0.0193 0.1245] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   311/423   -  73%
# Predicción: [0.7993 0.0153 0.1854] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   312/424   -  73%
# Predicción: [0.4591 0.4942 0.0467] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   313/425   -  73%
# Predicción: [0.8301 0.1626 0.0072] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   314/426   -  73%
# Predicción: [0.0056 0.001  0.9934] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   315/427   -  73%
# Predicción: [0.0597 0.6261 0.3142] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   315/428   -  73%
# Predicción: [0.2988 0.3593 0.3419] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   316/429   -  73%
# Predicción: [0.1987 0.0324 0.7689] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   316/430   -  73%
# Predicción: [0.9543 0.0431 0.0026] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   317/431   -  73%
# Predicción: [0.8208 0.1498 0.0294] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   318/432   -  73%
# Predicción: [0.1562 0.8304 0.0134] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   318/433   -  73%
# Predicción: [0.5313 0.4577 0.011 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   319/434   -  73%
# Predicción: [0.9526 0.0195 0.028 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   320/435   -  73%
# Predicción: [0.0585 0.0527 0.8888] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   321/436   -  73%
# Predicción: [0.9641 0.0074 0.0286] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   322/437   -  73%
# Predicción: [0.9987 0.0009 0.0005] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   323/438   -  73%
# Predicción: [0.9147 0.0685 0.0168] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   324/439   -  73%
# Predicción: [0.8158 0.1817 0.0025] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   325/440   -  73%
# Predicción: [0.6509 0.1714 0.1777] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   326/441   -  73%
# Predicción: [0.9524 0.0171 0.0305] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   327/442   -  73%
# Predicción: [0.1014 0.0165 0.8822] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   327/443   -  73%
# Predicción: [0.1075 0.1687 0.7238] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   327/444   -  73%
# Predicción: [0.2098 0.7777 0.0126] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   327/445   -  73%
# Predicción: [0.8692 0.0099 0.1209] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:   327/446   -  73%
# Predicción: [0.0492 0.0082 0.9426] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   328/447   -  73%
# Predicción: [0.6489 0.3476 0.0035] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   329/448   -  73%
# Predicción: [0.8843 0.094  0.0217] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   330/449   -  73%
# Predicción: [0.1908 0.0089 0.8003] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   331/450   -  73%
# Predicción: [0.8844 0.0227 0.0929] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   332/451   -  73%
# Predicción: [0.9137 0.0151 0.0712] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   333/452   -  73%
# Predicción: [0.4068 0.3796 0.2136] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   333/453   -  73%
# Predicción: [0.9723 0.0247 0.003 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   334/454   -  73%
# Predicción: [0.829  0.1592 0.0118] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   335/455   -  73%
# Predicción: [0.2638 0.4316 0.3046] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   335/456   -  73%
# Predicción: [0.9449 0.0059 0.0492] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   336/457   -  73%
# Predicción: [0.9432 0.0512 0.0057] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   337/458   -  73%
# Predicción: [0.1608 0.0295 0.8097] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   338/459   -  73%
# Predicción: [0.875  0.1213 0.0037] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   339/460   -  73%
# Predicción: [0.4179 0.0143 0.5678] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   339/461   -  73%
# Predicción: [0.8996 0.0923 0.0081] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   340/462   -  73%
# Predicción: [0.2418 0.7571 0.0012] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   340/463   -  73%
# Predicción: [0.1545 0.0166 0.8289] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   341/464   -  73%
# Predicción: [0.6639 0.2022 0.1339] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   341/465   -  73%
# Predicción: [0.9512 0.0037 0.0451] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   342/466   -  73%
# Predicción: [0.2869 0.0157 0.6973] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   342/467   -  73%
# Predicción: [0.0936 0.8954 0.011 ] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   343/468   -  73%
# Predicción: [0.9059 0.0074 0.0867] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   344/469   -  73%
# Predicción: [0.5198 0.0527 0.4275] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   345/470   -  73%
# Predicción: [0.0843 0.8467 0.0691] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   346/471   -  73%
# Predicción: [0.0429 0.9526 0.0045] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   347/472   -  73%
# Predicción: [0.9506 0.0368 0.0126] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   348/473   -  73%
# Predicción: [0.8519 0.1367 0.0114] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   348/474   -  73%
# Predicción: [0.0707 0.9063 0.023 ] -- Dice: 1 -- Real: 2  ❌  --- Aciertos:   348/475   -  73%
# Predicción: [0.8925 0.1007 0.0068] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   349/476   -  73%
# Predicción: [0.0651 0.0071 0.9278] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:   350/477   -  73%
# Predicción: [0.6569 0.3254 0.0177] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   351/478   -  73%
# Predicción: [0.097  0.8953 0.0078] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   352/479   -  73%
# Predicción: [0.9123 0.0104 0.0774] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   353/480   -  73%
# Predicción: [0.9476 0.0478 0.0046] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   354/481   -  73%
# Predicción: [0.8172 0.1779 0.0048] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   355/482   -  73%
# Predicción: [0.8988 0.0734 0.0278] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:   355/483   -  73%
# Predicción: [0.0351 0.0282 0.9368] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   355/484   -  73%
# Predicción: [0.8084 0.1851 0.0064] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   356/485   -  73%
# Predicción: [0.9646 0.0051 0.0303] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   357/486   -  73%
# Predicción: [0.4145 0.5699 0.0156] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   357/487   -  73%
# Predicción: [0.9455 0.0462 0.0084] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   358/488   -  73%
# Predicción: [0.3295 0.6306 0.0399] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   359/489   -  73%
# Predicción: [0.1249 0.008  0.8671] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   359/490   -  73%
# Predicción: [0.5323 0.008  0.4597] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   360/491   -  73%
# Predicción: [0.1818 0.3107 0.5075] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:   360/492   -  73%
# Predicción: [0.384  0.0818 0.5342] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:   360/493   -  73%
# Predicción: [0.9633 0.03   0.0067] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   361/494   -  73%
# Predicción: [0.1327 0.8641 0.0031] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   362/495   -  73%
# Predicción: [0.2937 0.6863 0.02  ] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:   362/496   -  72%
# Predicción: [0.812  0.1734 0.0147] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   363/497   -  73%
# Predicción: [0.804  0.1568 0.0392] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   364/498   -  73%
# Predicción: [0.0342 0.9643 0.0015] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   365/499   -  73%
# Predicción: [0.0466 0.9141 0.0393] -- Dice: 1 -- Real: 2  ❌  --- Aciertos:   365/500   -  73%
# Predicción: [0.9748 0.0055 0.0197] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   366/501   -  73%
# Predicción: [0.9076 0.0754 0.017 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   367/502   -  73%
# Predicción: [0.6024 0.3936 0.004 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   368/503   -  73%
# Predicción: [0.9518 0.0469 0.0013] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   369/504   -  73%
# Predicción: [0.1988 0.7854 0.0157] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:   370/505   -  73%
# Predicción: [0.9224 0.0062 0.0714] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   371/506   -  73%
# Predicción: [0.6296 0.0344 0.3361] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   372/507   -  73%
# Predicción: [0.609  0.2805 0.1105] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   373/508   -  73%
# Predicción: [0.7318 0.0097 0.2585] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   374/509   -  73%
# Predicción: [0.555  0.0619 0.3831] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:   375/510   -  73%
# ...
# Predicción: [0.0432 0.0334 0.9234] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2446/3181  -  76%
# Predicción: [0.0482 0.0071 0.9447] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2447/3182  -  76%
# Predicción: [0.035  0.9566 0.0084] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2448/3183  -  76%
# Predicción: [0.0101 0.9873 0.0025] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2449/3184  -  76%
# Predicción: [0.0124 0.0052 0.9824] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2450/3185  -  76%
# Predicción: [0.9682 0.0282 0.0036] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:  2450/3186  -  76%
# Predicción: [0.0927 0.8951 0.0122] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2451/3187  -  76%
# Predicción: [0.0196 0.9746 0.0058] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2452/3188  -  76%
# Predicción: [0.3598 0.0645 0.5757] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2453/3189  -  76%
# Predicción: [0.1088 0.0075 0.8837] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2454/3190  -  76%
# Predicción: [0.0553 0.9415 0.0032] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2455/3191  -  76%
# Predicción: [0.1237 0.01   0.8662] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2456/3192  -  76%
# Predicción:    [0.029 0.925 0.046] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2457/3193  -  76%
# Predicción: [0.4889 0.1381 0.373 ] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:  2457/3194  -  76%
# Predicción: [0.2908 0.6796 0.0296] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2458/3195  -  76%
# Predicción: [0.9202 0.0297 0.05  ] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:  2458/3196  -  76%
# Predicción: [0.9899 0.0017 0.0084] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2459/3197  -  76%
# Predicción: [0.1368 0.0398 0.8234] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2460/3198  -  76%
# Predicción: [0.8438 0.0576 0.0987] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2461/3199  -  76%
# Predicción: [0.0038 0.0023 0.9939] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2462/3200  -  76%
# Predicción: [0.0146 0.0037 0.9817] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2463/3201  -  76%
# Predicción: [0.4779 0.0509 0.4712] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:  2463/3202  -  76%
# Predicción: [0.6818 0.0034 0.3148] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:  2463/3203  -  76%
# Predicción: [0.0208 0.9777 0.0015] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2464/3204  -  76%
# Predicción: [0.9372 0.0622 0.0007] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:  2464/3205  -  76%
# Predicción: [0.6009 0.0439 0.3552] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:  2464/3206  -  76%
# Predicción: [0.5904 0.3525 0.0571] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:  2464/3207  -  76%
# Predicción: [0.3123 0.1202 0.5675] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:  2464/3208  -  76%
# Predicción: [0.0806 0.9108 0.0086] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2465/3209  -  76%
# Predicción: [0.8465 0.0353 0.1182] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:  2465/3210  -  76%
# Predicción:    [0.057 0.016 0.927] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2466/3211  -  76%
# Predicción: [0.8598 0.1359 0.0044] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:  2466/3212  -  76%
# Predicción: [0.3875 0.5736 0.0389] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2467/3213  -  76%
# Predicción: [0.0097 0.9893 0.001 ] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2468/3214  -  76%
# Predicción: [0.0449 0.9491 0.0059] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2469/3215  -  76%
# Predicción: [0.3375 0.284  0.3786] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2470/3216  -  76%
# Predicción: [0.203  0.7325 0.0645] -- Dice: 1 -- Real: 2  ❌  --- Aciertos:  2470/3217  -  76%
# Predicción: [0.0568 0.0028 0.9404] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2471/3218  -  76%
# Predicción: [0.0447 0.9487 0.0067] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2472/3219  -  76%
# Predicción: [0.7938 0.0597 0.1465] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:  2472/3220  -  76%
# Predicción: [0.0669 0.9283 0.0048] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2473/3221  -  76%
# Predicción: [0.002  0.0004 0.9976] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2474/3222  -  76%
# Predicción: [0.0106 0.9864 0.003 ] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2475/3223  -  76%
# Predicción: [0.9999 0.0001 0.0001] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2476/3224  -  76%
# Predicción: [0.0096 0.0025 0.9879] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2477/3225  -  76%
# Predicción: [0.1824 0.0262 0.7914] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2478/3226  -  76%
# Predicción: [0.0379 0.0048 0.9573] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2479/3227  -  76%
# Predicción: [0.8336 0.1589 0.0075] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:  2479/3228  -  76%
# Predicción: [0.096  0.8191 0.0849] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2480/3229  -  76%
# Predicción: [0.1484 0.75   0.1016] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2481/3230  -  76%
# Predicción: [0.2987 0.2119 0.4894] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2482/3231  -  76%
# Predicción: [0.035  0.0285 0.9365] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2483/3232  -  76%
# Predicción: [0.2994 0.6939 0.0067] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2484/3233  -  76%
# Predicción: [0.1916 0.3646 0.4438] -- Dice: 2 -- Real: 1  ❌  --- Aciertos:  2484/3234  -  76%
# Predicción: [0.105  0.8867 0.0083] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2485/3235  -  76%
# Predicción: [0.0399 0.0778 0.8823] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2486/3236  -  76%
# Predicción: [0.0486 0.8814 0.07  ] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2487/3237  -  76%
# Predicción: [0.0556 0.9427 0.0017] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2488/3238  -  76%
# Predicción: [0.0083 0.9911 0.0006] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2489/3239  -  76%
# Predicción: [0.9981 0.0001 0.0017] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2490/3240  -  76%
# Predicción: [0.174  0.1488 0.6773] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2491/3241  -  76%
# Predicción: [0.7985 0.0588 0.1427] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2492/3242  -  76%
# Predicción: [0.7741 0.0016 0.2243] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2493/3243  -  76%
# Predicción: [0.0246 0.009  0.9664] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2494/3244  -  76%
# Predicción: [0.0406 0.9503 0.0091] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2495/3245  -  76%
# Predicción: [0.2051 0.0021 0.7928] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:  2495/3246  -  76%
# Predicción: [0.6697 0.3146 0.0157] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2496/3247  -  76%
# Predicción: [0.0609 0.9322 0.0069] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2497/3248  -  76%
# Predicción: [0.9886 0.0016 0.0098] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2498/3249  -  76%
# Predicción: [0.4343 0.5434 0.0222] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2499/3250  -  76%
# Predicción: [0.4939 0.4903 0.0158] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2500/3251  -  76%
# Predicción: [0.849  0.0068 0.1442] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2501/3252  -  76%
# Predicción: [0.0124 0.0033 0.9842] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2502/3253  -  76%
# Predicción: [0.4706 0.0028 0.5266] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2503/3254  -  76%
# Predicción: [0.0085 0.9909 0.0007] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2504/3255  -  76%
# Predicción: [0.0481 0.9076 0.0443] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2505/3256  -  76%
# Predicción: [0.0088 0.9903 0.0009] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2506/3257  -  76%
# Predicción: [0.1418 0.0079 0.8503] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2507/3258  -  76%
# Predicción: [0.2764 0.0059 0.7177] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2508/3259  -  76%
# Predicción: [0.0696 0.0131 0.9174] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2509/3260  -  76%
# Predicción: [0.0771 0.8953 0.0276] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2510/3261  -  76%
# Predicción: [0.7773 0.0083 0.2144] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:  2510/3262  -  76%
# Predicción: [0.216  0.7819 0.0021] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:  2510/3263  -  76%
# Predicción: [0.952  0.0049 0.0431] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2511/3264  -  76%
# Predicción: [0.2461 0.7404 0.0136] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2512/3265  -  76%
# Predicción: [0.9343 0.0107 0.055 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2513/3266  -  76%
# Predicción: [0.6943 0.2337 0.072 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2514/3267  -  76%
# Predicción: [0.0083 0.9906 0.0011] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2515/3268  -  76%
# Predicción: [0.1889 0.0295 0.7816] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2516/3269  -  76%
# Predicción: [0.9602 0.0396 0.0002] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2517/3270  -  76%
# Predicción: [0.1636 0.0888 0.7476] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:  2517/3271  -  76%
# Predicción: [0.2152 0.7753 0.0095] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2518/3272  -  76%
# Predicción: [0.3711 0.6157 0.0132] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:  2518/3273  -  76%
# Predicción: [0.325  0.2814 0.3936] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2519/3274  -  76%
# Predicción: [0.8714 0.1212 0.0074] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2520/3275  -  76%
# Predicción: [0.9984 0.0006 0.001 ] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2521/3276  -  76%
# Predicción: [0.2461 0.1349 0.619 ] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2522/3277  -  76%
# Predicción: [0.4236 0.0148 0.5616] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2523/3278  -  76%
# Predicción: [0.0482 0.0015 0.9503] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2524/3279  -  76%
# Predicción: [0.0985 0.0506 0.8509] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2525/3280  -  76%
# Predicción: [0.8509 0.1374 0.0117] -- Dice: 0 -- Real: 1  ❌  --- Aciertos:  2525/3281  -  76%
# Predicción: [0.2087 0.7075 0.0838] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2526/3282  -  76%
# Predicción: [0.9147 0.0165 0.0688] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2527/3283  -  76%
# Predicción: [0.3161 0.6805 0.0035] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2528/3284  -  76%
# Predicción: [0.1092 0.8873 0.0035] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2529/3285  -  76%
# Predicción: [0.0198 0.968  0.0123] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2530/3286  -  76%
# Predicción: [0.0261 0.0096 0.9643] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2531/3287  -  77%
# Predicción: [0.1645 0.7042 0.1313] -- Dice: 1 -- Real: 2  ❌  --- Aciertos:  2531/3288  -  76%
# Predicción: [0.0294 0.0413 0.9293] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2532/3289  -  76%
# Predicción: [0.4398 0.0137 0.5466] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:  2532/3290  -  76%
# Predicción: [0.0682 0.9295 0.0024] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2533/3291  -  76%
# Predicción: [0.0344 0.0135 0.9521] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2534/3292  -  76%
# Predicción: [0.9826 0.0123 0.0051] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2535/3293  -  76%
# Predicción: [0.0716 0.0345 0.8939] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2536/3294  -  76%
# Predicción: [0.0824 0.9159 0.0017] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2537/3295  -  76%
# Predicción: [0.573  0.1122 0.3147] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2538/3296  -  77%
# Predicción: [0.0626 0.9326 0.0048] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2539/3297  -  77%
# Predicción: [0.2074 0.0105 0.7821] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2540/3298  -  77%
# Predicción: [0.0119 0.9866 0.0015] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2541/3299  -  77%
# Predicción: [0.0163 0.9784 0.0053] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2542/3300  -  77%
# Predicción: [0.0087 0.9898 0.0015] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2543/3301  -  77%
# Predicción: [0.464  0.3478 0.1883] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2544/3302  -  77%
# Predicción: [0.6087 0.0024 0.3888] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:  2544/3303  -  77%
# Predicción: [0.0191 0.0056 0.9752] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2545/3304  -  77%
# Predicción: [0.015  0.9834 0.0016] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2546/3305  -  77%
# Predicción: [0.6979 0.0266 0.2755] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2547/3306  -  77%
# Predicción: [0.5977 0.0276 0.3747] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2548/3307  -  77%
# Predicción: [0.6552 0.3325 0.0123] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2549/3308  -  77%
# Predicción: [0.6986 0.2606 0.0408] -- Dice: 0 -- Real: 2  ❌  --- Aciertos:  2549/3309  -  77%
# Predicción: [0.9233 0.0353 0.0414] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2550/3310  -  77%
# Predicción: [0.9336 0.0331 0.0334] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2551/3311  -  77%
# Predicción: [0.0458 0.9099 0.0443] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2552/3312  -  77%
# Predicción: [0.3685 0.0504 0.5811] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2553/3313  -  77%
# Predicción: [0.0676 0.9231 0.0093] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2554/3314  -  77%
# Predicción: [0.0149 0.9829 0.0022] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2555/3315  -  77%
# Predicción: [0.0219 0.9769 0.0012] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2556/3316  -  77%
# Predicción: [0.0214 0.01   0.9686] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2557/3317  -  77%
# Predicción: [0.4548 0.4816 0.0636] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2558/3318  -  77%
# Predicción: [0.0437 0.0089 0.9475] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2559/3319  -  77%
# Predicción: [0.1238 0.1048 0.7714] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2560/3320  -  77%
# Predicción: [0.0475 0.0086 0.9439] -- Dice: 2 -- Real: 0  ❌  --- Aciertos:  2560/3321  -  77%
# Predicción: [0.0297 0.9665 0.0038] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2561/3322  -  77%
# Predicción: [0.0026 0.9971 0.0003] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2562/3323  -  77%
# Predicción: [0.3573 0.6129 0.0298] -- Dice: 1 -- Real: 0  ❌  --- Aciertos:  2562/3324  -  77%
# Predicción: [0.7625 0.2283 0.0092] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2563/3325  -  77%
# Predicción: [0.0058 0.9936 0.0005] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2564/3326  -  77%
# Predicción: [0.0687 0.016  0.9153] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2565/3327  -  77%
# Predicción: [0.1837 0.8024 0.014 ] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2566/3328  -  77%
# Predicción: [0.2415 0.7367 0.0218] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2567/3329  -  77%
# Predicción: [0.1781 0.8136 0.0083] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2568/3330  -  77%
# Predicción: [0.9356 0.0012 0.0632] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2569/3331  -  77%
# Predicción: [0.0161 0.0052 0.9787] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2570/3332  -  77%
# Predicción: [0.0482 0.9496 0.0023] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2571/3333  -  77%
# Predicción: [0.0401 0.0226 0.9373] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2572/3334  -  77%
# Predicción: [0.9185 0.0779 0.0036] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2573/3335  -  77%
# Predicción: [0.1141 0.0611 0.8249] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2574/3336  -  77%
# Predicción: [0.1635 0.0558 0.7807] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2575/3337  -  77%
# Predicción: [0.9913 0.0081 0.0006] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2576/3338  -  77%
# Predicción: [0.3826 0.0044 0.613 ] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2577/3339  -  77%
# Predicción: [0.0083 0.9906 0.0012] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2578/3340  -  77%
# Predicción: [0.0182 0.9765 0.0052] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2579/3341  -  77%
# Predicción: [0.0097 0.0041 0.9862] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2580/3342  -  77%
# Predicción: [0.8986 0.0292 0.0722] -- Dice: 0 -- Real: 0  ✅  --- Aciertos:  2581/3343  -  77%
# Predicción: [0.2195 0.2009 0.5796] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2582/3344  -  77%
# Predicción: [0.248  0.7132 0.0388] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2583/3345  -  77%
# Predicción: [0.1238 0.0084 0.8679] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2584/3346  -  77%
# Predicción: [0.1628 0.7754 0.0619] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2585/3347  -  77%
# Predicción: [0.0057 0.0023 0.992 ] -- Dice: 2 -- Real: 2  ✅  --- Aciertos:  2586/3348  -  77%
# Predicción: [0.2358 0.7618 0.0024] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2587/3349  -  77%
# Predicción: [0.0255 0.9686 0.0058] -- Dice: 1 -- Real: 1  ✅  --- Aciertos:  2588/3350  -  77%

# %%
print(f"{sumaAciertos/len(res_pred)}")
# Out:
# 0.6591934644464237
